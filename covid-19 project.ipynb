# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("country_wise_latest.csv")

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# ### finding the country with highest no of cases

# %%
a=df['Confirmed'].max()
a
# Out:
# 4290259

# %%
maxcases=df.loc[df['Confirmed']==a]
maxcases
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %% [markdown]
# ### finding the country with lowest no of cases

# %%
b=df['Confirmed'].min()
b
# Out:
# 10

# %%
mincases=df.loc[df['Confirmed']==b]
mincases
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 183  Western Sahara         10       1          8       1          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 183           0              0                10.0                   80.0
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 183                    12.5                   10              0
#
#      1 week % increase WHO Region
# 183                0.0     Africa

# %% [markdown]
# ### finding the country with highest no of deaths

# %%
c=df['Deaths'].max()
c
# Out:
# 148011

# %%
maxDeaths=df.loc[df['Deaths']==c]
maxDeaths
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %% [markdown]
# ### finding the country with lowest no of deaths

# %%
d=df['Deaths'].min()
d
# Out:
# 0

# %%
minDeaths=df.loc[df['Deaths']==d]
minDeaths
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 19                             Bhutan         99       0         86      13
# 30                           Cambodia        226       0        147      79
# 49                           Dominica         18       0         18       0
# 55                            Eritrea        265       0        191      74
# 59                               Fiji         27       0         18       9
# 68                          Greenland         14       0         13       1
# 69                            Grenada         23       0         23       0
# 75                           Holy See         12       0         12       0
# 94                               Laos         20       0         19       1
# 114                          Mongolia        289       0        222      67
# 130                  Papua New Guinea         62       0         11      51
# ...

# %%
minDeaths.describe(include="all")
# Out:
#        Country/Region   Confirmed  Deaths   Recovered     Active  New cases  \
# count              17   17.000000    17.0   17.000000  17.000000  17.000000
# unique             17         NaN     NaN         NaN        NaN        NaN
# top            Bhutan         NaN     NaN         NaN        NaN        NaN
# freq                1         NaN     NaN         NaN        NaN        NaN
# mean              NaN  101.000000     0.0   72.941176  28.058824   1.176471
# std               NaN  125.068481     0.0  101.016998  32.024347   2.743977
# min               NaN   12.000000     0.0    0.000000   0.000000   0.000000
# 25%               NaN   20.000000     0.0   15.000000   1.000000   0.000000
# 50%               NaN   27.000000     0.0   22.000000  13.000000   0.000000
# 75%               NaN  114.000000     0.0   86.000000  66.000000   1.000000
# max               NaN  431.000000     0.0  365.000000  79.000000  11.000000
#
# ...

# %% [markdown]
# ### finding the percentage of recovery rate for every country

# %%
df1=pd.DataFrame(df,columns=['Country/Region','Confirmed','Recovered'])

# %%
df1['recovered percentage']=(df1['Recovered']/df1['Confirmed'])*100

# %%
df1
# Out:
#          Country/Region  Confirmed  Recovered  recovered percentage
# 0           Afghanistan      36263      25198             69.486805
# 1               Albania       4880       2745             56.250000
# 2               Algeria      27973      18837             67.339935
# 3               Andorra        907        803             88.533627
# 4                Angola        950        242             25.473684
# ..                  ...        ...        ...                   ...
# 182  West Bank and Gaza      10621       3752             35.326240
# 183      Western Sahara         10          8             80.000000
# 184               Yemen       1691        833             49.260792
# 185              Zambia       4552       2815             61.840949
# 186            Zimbabwe       2704        542             20.044379
#
# [187 rows x 4 columns]

# %% [markdown]
# ### finding the country with most recovery rate

# %%
a=df1['recovered percentage'].max()
a
# Out:
# 100.0

# %%
high=df1.loc[df1['recovered percentage']==a]

# %%
high
# Out:
#    Country/Region  Confirmed  Recovered  recovered percentage
# 49       Dominica         18         18                 100.0
# 69        Grenada         23         23                 100.0
# 75       Holy See         12         12                 100.0

# %%
high.describe(include="all")
# Out:
#        Country/Region  Confirmed  Recovered  recovered percentage
# count               3   3.000000   3.000000                   3.0
# unique              3        NaN        NaN                   NaN
# top          Dominica        NaN        NaN                   NaN
# freq                1        NaN        NaN                   NaN
# mean              NaN  17.666667  17.666667                 100.0
# std               NaN   5.507571   5.507571                   0.0
# min               NaN  12.000000  12.000000                 100.0
# 25%               NaN  15.000000  15.000000                 100.0
# 50%               NaN  18.000000  18.000000                 100.0
# 75%               NaN  20.500000  20.500000                 100.0
# max               NaN  23.000000  23.000000                 100.0

# %% [markdown]
# ### finding the country with less recovery rate

# %%
b=df1['recovered percentage'].min()
lessrecovery=df1.loc[df1['recovered percentage']==b]

# %%
lessrecovery
# Out:
#     Country/Region  Confirmed  Recovered  recovered percentage
# 32          Canada     116458          0                   0.0
# 117     Mozambique       1701          0                   0.0
# 147         Serbia      24141          0                   0.0
# 161         Sweden      79395          0                   0.0
# 163          Syria        674          0                   0.0
# 168    Timor-Leste         24          0                   0.0

# %%
lessrecovery.describe(include="all")
# Out:
#        Country/Region      Confirmed  Recovered  recovered percentage
# count               6       6.000000        6.0                   6.0
# unique              6            NaN        NaN                   NaN
# top            Canada            NaN        NaN                   NaN
# freq                1            NaN        NaN                   NaN
# mean              NaN   37065.500000        0.0                   0.0
# std               NaN   49414.694538        0.0                   0.0
# min               NaN      24.000000        0.0                   0.0
# 25%               NaN     930.750000        0.0                   0.0
# 50%               NaN   12921.000000        0.0                   0.0
# 75%               NaN   65581.500000        0.0                   0.0
# max               NaN  116458.000000        0.0                   0.0

# %% [markdown]
# ### finding the average rate for all countries

# %%
country=df1['recovered percentage'].mean()
country
# Out:
# 64.82033679451074

# %% [markdown]
# ### finding the countries which are having recovery rate less than average recovery rate

# %%
less=df1.loc[df1['recovered percentage']<=country]

# %%
less.head(20)
# Out:
#               Country/Region  Confirmed  Recovered  recovered percentage
# 1                    Albania       4880       2745             56.250000
# 4                     Angola        950        242             25.473684
# 6                  Argentina     167416      72575             43.350098
# 8                  Australia      15303       9311             60.844279
# 11                   Bahamas        382         91             23.821990
# 13                Bangladesh     226225     125683             55.556636
# 16                   Belgium      66428      17452             26.272054
# 17                    Belize         48         26             54.166667
# 18                     Benin       1770       1036             58.531073
# 20                   Bolivia      71181      21478             30.173782
# 21    Bosnia and Herzegovina      10498       4930             46.961326
# 22                  Botswana        739         63              8.525034
# ...

# %%
less.sort_values(by=['recovered percentage'])
# Out:
#        Country/Region  Confirmed  Recovered  recovered percentage
# 147            Serbia      24141          0              0.000000
# 161            Sweden      79395          0              0.000000
# 117        Mozambique       1701          0              0.000000
# 163             Syria        674          0              0.000000
# 168       Timor-Leste         24          0              0.000000
# ..                ...        ...        ...                   ...
# 131          Paraguay       4548       2905             63.874230
# 79              India    1480073     951166             64.264803
# 89         Kazakhstan      84648      54404             64.270863
# 40   Congo (Kinshasa)       8844       5700             64.450475
# 103        Madagascar       9690       6260             64.602683
#
# [79 rows x 4 columns]

# %%
less.count()
# Out:
# Country/Region          79
# Confirmed               79
# Recovered               79
# recovered percentage    79
# dtype: int64

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# ### country with highest active cases

# %%
e=df['Active'].max()
e
# Out:
# 2816444

# %%
maxActive=df.loc[df['Active']==e]
maxActive
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                   30.9
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 173              11.88   Americas

# %% [markdown]
# ### Country with lowest active cases

# %%
f=df['Active'].min()
f
# Out:
# 0

# %%
minActive=df.loc[df['Active']==f]
minActive
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 24          Brunei        141       3        138       0          0
# 49        Dominica         18       0         18       0          0
# 69         Grenada         23       0         23       0          0
# 75        Holy See         12       0         12       0          0
# 143     San Marino        699      42        657       0          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 24            0              0                2.13                  97.87
# 49            0              0                0.00                 100.00
# 69            0              0                0.00                 100.00
# 75            0              0                0.00                 100.00
# 143           0              0                6.01                  93.99
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df['WHO Region'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
X = df.drop(["Country/Region","New cases","New deaths","New recovered","Deaths / 100 Cases","WHO Region","1 week % increase","1 week change","Recovered / 100 Cases","Confirmed last week","Deaths / 100 Recovered"],axis=1)
Y = df["Confirmed last week"]

# %%
X.head()
# Out:
#    Confirmed  Deaths  Recovered  Active
# 0      36263    1269      25198    9796
# 1       4880     144       2745    1991
# 2      27973    1163      18837    7973
# 3        907      52        803      52
# 4        950      41        242     667

# %%
X.shape
# Out:
# (187, 4)

# %%
Y.shape
# Out:
# (187,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (149, 4)

# %%
X_test.shape
# Out:
# (38, 4)

# %%
Y_train.shape
# Out:
# (149,)

# %%
Y_test.shape
# Out:
# (38,)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([ 0.95438359,  1.36878717, -0.08350798, -0.33089561])

# %%
regression.intercept_
# Out:
# 2841.8539510711635

# %%
coeff_df = pd.DataFrame(regression.coef_,X.columns,columns=["Coefficient"])
coeff_df
# Out:
#            Coefficient
# Confirmed     0.954384
# Deaths        1.368787
# Recovered    -0.083508
# Active       -0.330896

# %%
Y_pred = regression.predict(X_train)
print(Y_pred)
# Out:
# [   3586.54913543   14970.36380494   45888.26303569   70072.05579503
#   269228.92008882    4723.0381354    31463.95934746    2969.00429787
#     3019.12821686    4637.41877124    9725.5360796     3567.32079595
#     3240.17460942    2924.85459754    3511.59240047   10861.6587565
#     5051.56975575    4768.95933617   65270.60691689   71480.24605325
#    22545.75720329   52077.0256391    10119.6251828    87993.91501893
#     3321.5963577     2979.39325138   16471.24735315   40879.31569299
#     6469.22472301    5771.70358457   11378.053673      3142.51002966
#     5374.31115771    5597.97650074   15977.0210064     2851.76761472
#     3913.09604146    8565.66240148   26919.45515928    2863.14110395
#    10524.69347069    8128.71250484    7095.072413     28293.31818973
#    57346.26859087    3163.16159325   15522.06691885    5765.69834751
#    97758.94594563    2946.70560169    4263.08922499    3250.65373563
#    19159.07539811   52155.20144513   11134.10185342    3208.77719294
# ...

# %%
df = pd.DataFrame({'Actual' : Y_train, 'Predicted' : Y_pred})
df.tail()
# Out:
#      Actual      Predicted
# 103    7153   10586.770204
# 67     4012    6160.584183
# 117    1507    3921.103523
# 47    13453   15581.898699
# 172  220572  206022.113403

# %%
from sklearn import metrics
print("Mean Absolute Error :",metrics.mean_absolute_error(Y_train,Y_pred))
print("Mean Square Error :",metrics.mean_absolute_error(Y_train,Y_pred))
print("Root Mean Squared Error :",np.sqrt(metrics.mean_squared_error(Y_train,Y_pred)))
# Out:
# Mean Absolute Error : 5027.174770675983
# Mean Square Error : 5027.174770675983
# Root Mean Squared Error : 11110.913521051512

# %%
from sklearn.metrics import r2_score
print("R2 error :",metrics.r2_score(Y_train,Y_pred))
# Out:
# R2 error : 0.9972853885898265
